# %%
# !pip install tensorflow keras pandas numpy scikit-learn

# %%
# !pip install kaggle
# !mkdir ~/.kaggle
# !cp kaggle.json ~/.kaggle/  # upload your kaggle.json file
# !chmod 600 ~/.kaggle/kaggle.json
# !kaggle datasets download -d kmader/skin-cancer-mnist-ham10000
# !unzip skin-cancer-mnist-ham10000.zip -d ./data/
# Out:
# ...
# mkdir: cannot create directory ‘/root/.kaggle’: File exists
# cp: cannot stat 'kaggle.json': No such file or directory
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory
# Dataset URL: https://www.kaggle.com/datasets/kmader/skin-cancer-mnist-ham10000
# License(s): CC-BY-NC-SA-4.0
# skin-cancer-mnist-ham10000.zip: Skipping, found more recently modified local copy (use --force to force download)
# Archive:  skin-cancer-mnist-ham10000.zip
# replace ./data/HAM10000_images_part_1/ISIC_0024306.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
import pandas as pd
import os

# Path to the extracted dataset folder
data_dir = './data/'

# Load the metadata CSV file
metadata = pd.read_csv(os.path.join(data_dir, 'HAM10000_metadata.csv'))

# Display the first few rows
metadata.head()
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear

# %%
# Check if the image file has different extensions
image_id = row['image_id']
img_path = None

for ext in ['jpg', 'jpeg', 'png']:
    temp_path = os.path.join(data_dir, 'images', image_id + f'.{ext}')
    if os.path.exists(temp_path):import numpy as np
import cv2
from tensorflow.keras.utils import to_categorical

IMG_SIZE = 224

# Function to load and preprocess an image
def load_image(image_id, img_size=IMG_SIZE):
    img_path = os.path.join(data_dir, 'images', image_id + '.jpg')

    # Check if the image file exists
    if not os.path.exists(img_path):
        print(f"Error: Image file not found: {img_path}")
        return None  # Or handle the error differently

    img = cv2.imread(img_path)

    # Check if the image was loaded successfully
    if img is None:
        print(f"Error: Failed to load image: {img_path}")
        return None  # Or handle the error differently

    img = cv2.resize(img, (img_size, img_size))
    img = img / 255.0  # Normalize to [0, 1]
    return img

# Load and preprocess the images and labels
X = []
y = []

for index, row in metadata.iterrows():
    image = load_image(row['image_id'])
    # Skip if image loading failed
    if image is not None:
        X.append(image)
        y.append(row['dx'])  # Label column
    else:
        print(f"Skipping image: {row['image_id']}")  # Print a message for skipped images

# Convert the image list to NumPy array
X = np.array(X)

# Check if X or y is empty and handle the case
if X.size == 0 or len(y) == 0:  # Check if either X or y is empty
    print("Error: No images or labels were loaded. Check your data path and image loading function.")
    # You can exit the script or handle the error differently here
    # For example:
    # import sys
    # sys.exit(1)


# Convert labels to numerical values
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y_encoded = le.fit_transform(y)

# Convert labels to one-hot encoding
# Check if y_encoded is empty before calling to_categorical
if y_encoded.size > 0:
    y_onehot = to_categorical(y_encoded)
else:
    print("Error: y_encoded is empty. Cannot perform one-hot encoding.")
    # Handle the error appropriately, e.g., assign an empty array or exit
    y_onehot = np.array([])  # Or sys.exit(1)

# Check shapes
print(f"Image data shape: {X.shape}")
print(f"Label data shape: {y_onehot.shape}")
        img_path = temp_path
        break

if img_path:
    img = cv2.imread(img_path)
# Out:
#   File "<ipython-input-24-5343d737ad61>", line 75
#     img_path = temp_path
#     ^
# IndentationError: unexpected indent

# %%
# Load a sample image manually
img_path = os.path.join(data_dir, 'images', 'ISIC_0024306.jpg')  # Replace with actual image ID

img = cv2.imread(img_path)
if img is None:
    print(f"Failed to load {img_path}")
else:
    print(f"Successfully loaded {img_path}")

# %%
# Convert the image list to NumPy array
X = np.array(X)

# Check if X is empty and handle the case
if X.size == 0:
    print("Error: No images were loaded. Check your data path and image loading function.")
    # You can exit the script or handle the error differently here
    # For example:
    # import sys
    # sys.exit(1)

# %%
y_encoded.shape

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y_encoded = le.fit_transform(y)

# Convert labels to one-hot encoding
y_onehot = to_categorical(y_encoded)

# Check shapes
print(f"Image data shape: {X.shape}")
print(f"Label data shape: {y_onehot.shape}")
